# %% [markdown]
# # Tensorflow를 이용한 LinerRegression

# %%
import tensorflow as tf
import numpy as np

#x_data = [1, 2, 3]
#y_data = [1, 2, 3]
x_data = np.arange(0,10)
y_data = x_data * 2 + 10


W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")
print(X)
print(Y)

hypothesis = W * X + b

# 손실 함수를 작성합니다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# 텐서플로우에 기본적으로 포함되어 있는 함수를 이용해 경사 하강법 최적화를 수행합니다.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
# 비용을 최소화 하는 것이 최종 목표
train_op = optimizer.minimize(cost)

epochs = 500
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # 최적화를 100번 수행합니다.
    for step in range(1, epochs+1):
        # sess.run 을 통해 train_op 와 cost 그래프를 계산합니다.
        # 이 때, 가설 수식에 넣어야 할 실제값을 feed_dict 을 통해 전달합니다.
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})
        if step %20 == 0:
            print(step, cost_val, sess.run(W), sess.run(b))

    # 최적화가 완료된 모델에 테스트 값을 넣고 결과가 잘 나오는지 확인해봅니다.
    print("\n=== Test ===")
    print("X: 5, Y:%f, Y':%f"%(5*2+10, sess.run(hypothesis, feed_dict={X: 5})))
    print("X: 2.5, Y:%f, Y':%f"%(2.5*2+10, sess.run(hypothesis, feed_dict={X: 2.5})))
# Out:
# Tensor("X_8:0", dtype=float32)
# Tensor("Y_8:0", dtype=float32)
# 20 20.110651 [3.3215618] [1.7130326]
# 40 16.034113 [3.1800404] [2.6004553]
# 60 12.783909 [3.053674] [3.3928463]
# 80 10.192539 [2.9408398] [4.1003838]
# 100 8.126456 [2.8400886] [4.7321525]
# 120 6.479178 [2.7501264] [5.2962685]
# 140 5.1658134 [2.669798] [5.7999744]
# 160 4.118673 [2.5980713] [6.2497416]
# 180 3.2837925 [2.534026] [6.651345]
# 200 2.6181493 [2.4768388] [7.009941]
# 220 2.0874362 [2.4257758] [7.330136]
# 240 1.6643015 [2.380181] [7.616042]
# 260 1.3269389 [2.339469] [7.871331]
# 280 1.057963 [2.3031166] [8.099281]
# 300 0.84350765 [2.2706568] [8.302823]
# 320 0.67252266 [2.241673] [8.48457]
# 340 0.536198 [2.215793] [8.6468525]
# 360 0.42750722 [2.1926842] [8.791757]
# 380 0.34084928 [2.1720505] [8.921144]
# 400 0.27175754 [2.153626] [9.0366745]
# 420 0.21666989 [2.1371746] [9.139834]
# 440 0.17275034 [2.1224852] [9.231946]
# 460 0.13773355 [2.109369] [9.314192]
# 480 0.10981444 [2.0976572] [9.387632]
# 500 0.087554276 [2.0871994] [9.453209]
#
# === Test ===
# X: 5, Y:20.000000, Y':19.889206
# X: 2.5, Y:15.000000, Y':14.671207

# %% [markdown]
# # Keras를 이용한 Linear Regress

# %%
import keras
import numpy as np

x_data = np.arange(0,10)
y_data = x_data * 2 + 10

model = keras.models.Sequential()
model.add(keras.layers.Dense(1, input_shape=(1,)))
model.compile('SGD', 'mse')

model.fit(x_data, y_data, epochs=500, verbose=2)

print("X: 5, Y:%f, Y':%f"%(5*2+10,  model.predict([5])))
print("X: 2.5, Y:%f, Y':%f"%(12.5*2+10,  model.predict([2.5])))
# Out:
# Epoch 1/500
#  - 0s - loss: 488.9472
# Epoch 2/500
#  - 0s - loss: 105.2270
# Epoch 3/500
#  - 0s - loss: 38.7007
# Epoch 4/500
#  - 0s - loss: 26.9763
# Epoch 5/500
#  - 0s - loss: 24.7222
# Epoch 6/500
#  - 0s - loss: 24.1069
# Epoch 7/500
#  - 0s - loss: 23.7772
# Epoch 8/500
#  - 0s - loss: 23.4993
# Epoch 9/500
#  - 0s - loss: 23.2329
# Epoch 10/500
#  - 0s - loss: 22.9709
# Epoch 11/500
#  - 0s - loss: 22.7122
# Epoch 12/500
#  - 0s - loss: 22.4564
# Epoch 13/500
#  - 0s - loss: 22.2034
# Epoch 14/500
#  - 0s - loss: 21.9534
# Epoch 15/500
#  - 0s - loss: 21.7061
# Epoch 16/500
#  - 0s - loss: 21.4617
# Epoch 17/500
#  - 0s - loss: 21.2199
# Epoch 18/500
#  - 0s - loss: 20.9809
# Epoch 19/500
#  - 0s - loss: 20.7446
# Epoch 20/500
#  - 0s - loss: 20.5110
# Epoch 21/500
#  - 0s - loss: 20.2800
# Epoch 22/500
#  - 0s - loss: 20.0516
# Epoch 23/500
#  - 0s - loss: 19.8258
# Epoch 24/500
#  - 0s - loss: 19.6025
# Epoch 25/500
#  - 0s - loss: 19.3817
# Epoch 26/500
#  - 0s - loss: 19.1634
# Epoch 27/500
#  - 0s - loss: 18.9476
# Epoch 28/500
#  - 0s - loss: 18.7342
# Epoch 29/500
#  - 0s - loss: 18.5232
# Epoch 30/500
#  - 0s - loss: 18.3146
# Epoch 31/500
#  - 0s - loss: 18.1083
# Epoch 32/500
#  - 0s - loss: 17.9043
# Epoch 33/500
#  - 0s - loss: 17.7027
# Epoch 34/500
#  - 0s - loss: 17.5033
# Epoch 35/500
#  - 0s - loss: 17.3062
# Epoch 36/500
#  - 0s - loss: 17.1113
# Epoch 37/500
#  - 0s - loss: 16.9185
# Epoch 38/500
#  - 0s - loss: 16.7280
# Epoch 39/500
#  - 0s - loss: 16.5396
# Epoch 40/500
#  - 0s - loss: 16.3533
# Epoch 41/500
#  - 0s - loss: 16.1691
# Epoch 42/500
#  - 0s - loss: 15.9870
# Epoch 43/500
#  - 0s - loss: 15.8070
# Epoch 44/500
#  - 0s - loss: 15.6289
# Epoch 45/500
#  - 0s - loss: 15.4529
# Epoch 46/500
#  - 0s - loss: 15.2789
# Epoch 47/500
#  - 0s - loss: 15.1068
# Epoch 48/500
#  - 0s - loss: 14.9367
# Epoch 49/500
#  - 0s - loss: 14.7684
# Epoch 50/500
#  - 0s - loss: 14.6021
# Epoch 51/500
#  - 0s - loss: 14.4376
# Epoch 52/500
#  - 0s - loss: 14.2750
# Epoch 53/500
#  - 0s - loss: 14.1143
# Epoch 54/500
#  - 0s - loss: 13.9553
# Epoch 55/500
#  - 0s - loss: 13.7981
# Epoch 56/500
#  - 0s - loss: 13.6427
# Epoch 57/500
#  - 0s - loss: 13.4891
# Epoch 58/500
#  - 0s - loss: 13.3371
# Epoch 59/500
#  - 0s - loss: 13.1869
# Epoch 60/500
#  - 0s - loss: 13.0384
# Epoch 61/500
#  - 0s - loss: 12.8916
# Epoch 62/500
#  - 0s - loss: 12.7464
# Epoch 63/500
#  - 0s - loss: 12.6028
# Epoch 64/500
#  - 0s - loss: 12.4609
# Epoch 65/500
#  - 0s - loss: 12.3205
# Epoch 66/500
#  - 0s - loss: 12.1818
# Epoch 67/500
#  - 0s - loss: 12.0446
# Epoch 68/500
#  - 0s - loss: 11.9089
# Epoch 69/500
#  - 0s - loss: 11.7748
# Epoch 70/500
#  - 0s - loss: 11.6422
# Epoch 71/500
#  - 0s - loss: 11.5110
# Epoch 72/500
#  - 0s - loss: 11.3814
# Epoch 73/500
#  - 0s - loss: 11.2532
# Epoch 74/500
#  - 0s - loss: 11.1265
# Epoch 75/500
#  - 0s - loss: 11.0012
# Epoch 76/500
#  - 0s - loss: 10.8773
# Epoch 77/500
#  - 0s - loss: 10.7548
# Epoch 78/500
#  - 0s - loss: 10.6336
# Epoch 79/500
#  - 0s - loss: 10.5139
# Epoch 80/500
#  - 0s - loss: 10.3954
# Epoch 81/500
#  - 0s - loss: 10.2784
# Epoch 82/500
#  - 0s - loss: 10.1626
# Epoch 83/500
#  - 0s - loss: 10.0481
# Epoch 84/500
#  - 0s - loss: 9.9350
# Epoch 85/500
#  - 0s - loss: 9.8231
# Epoch 86/500
#  - 0s - loss: 9.7124
# Epoch 87/500
#  - 0s - loss: 9.6031
# Epoch 88/500
#  - 0s - loss: 9.4949
# Epoch 89/500
#  - 0s - loss: 9.3880
# Epoch 90/500
#  - 0s - loss: 9.2822
# Epoch 91/500
#  - 0s - loss: 9.1777
# Epoch 92/500
#  - 0s - loss: 9.0743
# Epoch 93/500
#  - 0s - loss: 8.9721
# Epoch 94/500
#  - 0s - loss: 8.8711
# Epoch 95/500
#  - 0s - loss: 8.7712
# Epoch 96/500
#  - 0s - loss: 8.6724
# Epoch 97/500
#  - 0s - loss: 8.5747
# Epoch 98/500
#  - 0s - loss: 8.4781
# Epoch 99/500
#  - 0s - loss: 8.3826
# Epoch 100/500
#  - 0s - loss: 8.2882
# Epoch 101/500
#  - 0s - loss: 8.1949
# Epoch 102/500
#  - 0s - loss: 8.1026
# Epoch 103/500
#  - 0s - loss: 8.0113
# Epoch 104/500
#  - 0s - loss: 7.9211
# Epoch 105/500
#  - 0s - loss: 7.8319
# Epoch 106/500
#  - 0s - loss: 7.7437
# Epoch 107/500
#  - 0s - loss: 7.6565
# Epoch 108/500
#  - 0s - loss: 7.5702
# Epoch 109/500
#  - 0s - loss: 7.4850
# Epoch 110/500
#  - 0s - loss: 7.4007
# Epoch 111/500
#  - 0s - loss: 7.3173
# Epoch 112/500
#  - 0s - loss: 7.2349
# Epoch 113/500
#  - 0s - loss: 7.1534
# Epoch 114/500
#  - 0s - loss: 7.0729
# Epoch 115/500
#  - 0s - loss: 6.9932
# Epoch 116/500
#  - 0s - loss: 6.9144
# Epoch 117/500
#  - 0s - loss: 6.8366
# Epoch 118/500
#  - 0s - loss: 6.7596
# Epoch 119/500
#  - 0s - loss: 6.6834
# Epoch 120/500
#  - 0s - loss: 6.6082
# Epoch 121/500
#  - 0s - loss: 6.5337
# Epoch 122/500
#  - 0s - loss: 6.4601
# Epoch 123/500
#  - 0s - loss: 6.3874
# Epoch 124/500
#  - 0s - loss: 6.3155
# Epoch 125/500
#  - 0s - loss: 6.2443
# Epoch 126/500
#  - 0s - loss: 6.1740
# Epoch 127/500
#  - 0s - loss: 6.1045
# Epoch 128/500
#  - 0s - loss: 6.0357
# Epoch 129/500
#  - 0s - loss: 5.9677
# Epoch 130/500
#  - 0s - loss: 5.9005
# Epoch 131/500
#  - 0s - loss: 5.8341
# Epoch 132/500
#  - 0s - loss: 5.7684
# Epoch 133/500
#  - 0s - loss: 5.7034
# Epoch 134/500
#  - 0s - loss: 5.6392
# Epoch 135/500
#  - 0s - loss: 5.5756
# Epoch 136/500
#  - 0s - loss: 5.5128
# Epoch 137/500
#  - 0s - loss: 5.4508
# Epoch 138/500
#  - 0s - loss: 5.3894
# Epoch 139/500
#  - 0s - loss: 5.3287
# Epoch 140/500
#  - 0s - loss: 5.2687
# Epoch 141/500
#  - 0s - loss: 5.2093
# Epoch 142/500
#  - 0s - loss: 5.1506
# Epoch 143/500
#  - 0s - loss: 5.0926
# Epoch 144/500
#  - 0s - loss: 5.0353
# Epoch 145/500
#  - 0s - loss: 4.9786
# Epoch 146/500
#  - 0s - loss: 4.9225
# Epoch 147/500
#  - 0s - loss: 4.8671
# Epoch 148/500
#  - 0s - loss: 4.8122
# Epoch 149/500
#  - 0s - loss: 4.7580
# Epoch 150/500
#  - 0s - loss: 4.7044
# Epoch 151/500
#  - 0s - loss: 4.6515
# Epoch 152/500
#  - 0s - loss: 4.5991
# Epoch 153/500
#  - 0s - loss: 4.5473
# Epoch 154/500
#  - 0s - loss: 4.4961
# Epoch 155/500
#  - 0s - loss: 4.4454
# Epoch 156/500
#  - 0s - loss: 4.3954
# Epoch 157/500
#  - 0s - loss: 4.3459
# Epoch 158/500
#  - 0s - loss: 4.2969
# Epoch 159/500
#  - 0s - loss: 4.2485
# Epoch 160/500
#  - 0s - loss: 4.2007
# Epoch 161/500
#  - 0s - loss: 4.1534
# Epoch 162/500
#  - 0s - loss: 4.1066
# Epoch 163/500
#  - 0s - loss: 4.0603
# Epoch 164/500
#  - 0s - loss: 4.0146
# Epoch 165/500
#  - 0s - loss: 3.9694
# Epoch 166/500
#  - 0s - loss: 3.9247
# Epoch 167/500
#  - 0s - loss: 3.8805
# Epoch 168/500
#  - 0s - loss: 3.8368
# Epoch 169/500
#  - 0s - loss: 3.7936
# Epoch 170/500
#  - 0s - loss: 3.7508
# Epoch 171/500
#  - 0s - loss: 3.7086
# Epoch 172/500
#  - 0s - loss: 3.6668
# Epoch 173/500
#  - 0s - loss: 3.6255
# Epoch 174/500
#  - 0s - loss: 3.5847
# Epoch 175/500
#  - 0s - loss: 3.5443
# Epoch 176/500
#  - 0s - loss: 3.5044
# Epoch 177/500
#  - 0s - loss: 3.4649
# Epoch 178/500
#  - 0s - loss: 3.4259
# Epoch 179/500
#  - 0s - loss: 3.3873
# Epoch 180/500
#  - 0s - loss: 3.3492
# Epoch 181/500
#  - 0s - loss: 3.3114
# Epoch 182/500
#  - 0s - loss: 3.2742
# Epoch 183/500
#  - 0s - loss: 3.2373
# Epoch 184/500
#  - 0s - loss: 3.2008
# Epoch 185/500
#  - 0s - loss: 3.1648
# Epoch 186/500
#  - 0s - loss: 3.1291
# Epoch 187/500
#  - 0s - loss: 3.0939
# Epoch 188/500
#  - 0s - loss: 3.0590
# Epoch 189/500
#  - 0s - loss: 3.0246
# Epoch 190/500
#  - 0s - loss: 2.9905
# Epoch 191/500
#  - 0s - loss: 2.9568
# Epoch 192/500
#  - 0s - loss: 2.9235
# Epoch 193/500
#  - 0s - loss: 2.8906
# Epoch 194/500
#  - 0s - loss: 2.8581
# Epoch 195/500
#  - 0s - loss: 2.8259
# Epoch 196/500
#  - 0s - loss: 2.7940
# Epoch 197/500
#  - 0s - loss: 2.7626
# Epoch 198/500
#  - 0s - loss: 2.7315
# Epoch 199/500
#  - 0s - loss: 2.7007
# Epoch 200/500
#  - 0s - loss: 2.6703
# Epoch 201/500
#  - 0s - loss: 2.6402
# Epoch 202/500
#  - 0s - loss: 2.6105
# Epoch 203/500
#  - 0s - loss: 2.5811
# Epoch 204/500
#  - 0s - loss: 2.5520
# Epoch 205/500
#  - 0s - loss: 2.5232
# Epoch 206/500
#  - 0s - loss: 2.4948
# Epoch 207/500
#  - 0s - loss: 2.4667
# Epoch 208/500
#  - 0s - loss: 2.4390
# Epoch 209/500
#  - 0s - loss: 2.4115
# Epoch 210/500
#  - 0s - loss: 2.3843
# Epoch 211/500
#  - 0s - loss: 2.3575
# Epoch 212/500
#  - 0s - loss: 2.3309
# Epoch 213/500
#  - 0s - loss: 2.3047
# Epoch 214/500
#  - 0s - loss: 2.2787
# Epoch 215/500
#  - 0s - loss: 2.2530
# Epoch 216/500
#  - 0s - loss: 2.2277
# Epoch 217/500
#  - 0s - loss: 2.2026
# Epoch 218/500
#  - 0s - loss: 2.1778
# Epoch 219/500
#  - 0s - loss: 2.1532
# Epoch 220/500
#  - 0s - loss: 2.1290
# Epoch 221/500
#  - 0s - loss: 2.1050
# Epoch 222/500
#  - 0s - loss: 2.0813
# Epoch 223/500
#  - 0s - loss: 2.0579
# Epoch 224/500
#  - 0s - loss: 2.0347
# Epoch 225/500
#  - 0s - loss: 2.0118
# Epoch 226/500
#  - 0s - loss: 1.9891
# Epoch 227/500
#  - 0s - loss: 1.9667
# Epoch 228/500
#  - 0s - loss: 1.9446
# Epoch 229/500
#  - 0s - loss: 1.9227
# Epoch 230/500
#  - 0s - loss: 1.9010
# Epoch 231/500
#  - 0s - loss: 1.8796
# Epoch 232/500
#  - 0s - loss: 1.8584
# Epoch 233/500
#  - 0s - loss: 1.8375
# Epoch 234/500
#  - 0s - loss: 1.8168
# Epoch 235/500
#  - 0s - loss: 1.7963
# Epoch 236/500
#  - 0s - loss: 1.7761
# Epoch 237/500
#  - 0s - loss: 1.7561
# Epoch 238/500
#  - 0s - loss: 1.7363
# Epoch 239/500
#  - 0s - loss: 1.7168
# Epoch 240/500
#  - 0s - loss: 1.6974
# Epoch 241/500
#  - 0s - loss: 1.6783
# Epoch 242/500
#  - 0s - loss: 1.6594
# Epoch 243/500
#  - 0s - loss: 1.6407
# Epoch 244/500
#  - 0s - loss: 1.6222
# Epoch 245/500
#  - 0s - loss: 1.6040
# Epoch 246/500
#  - 0s - loss: 1.5859
# Epoch 247/500
#  - 0s - loss: 1.5680
# Epoch 248/500
#  - 0s - loss: 1.5504
# Epoch 249/500
#  - 0s - loss: 1.5329
# Epoch 250/500
#  - 0s - loss: 1.5157
# Epoch 251/500
#  - 0s - loss: 1.4986
# Epoch 252/500
#  - 0s - loss: 1.4817
# Epoch 253/500
#  - 0s - loss: 1.4650
# Epoch 254/500
#  - 0s - loss: 1.4485
# Epoch 255/500
#  - 0s - loss: 1.4322
# Epoch 256/500
#  - 0s - loss: 1.4161
# Epoch 257/500
#  - 0s - loss: 1.4001
# Epoch 258/500
#  - 0s - loss: 1.3844
# Epoch 259/500
#  - 0s - loss: 1.3688
# Epoch 260/500
#  - 0s - loss: 1.3534
# Epoch 261/500
#  - 0s - loss: 1.3381
# Epoch 262/500
#  - 0s - loss: 1.3230
# Epoch 263/500
#  - 0s - loss: 1.3081
# Epoch 264/500
#  - 0s - loss: 1.2934
# Epoch 265/500
#  - 0s - loss: 1.2788
# Epoch 266/500
#  - 0s - loss: 1.2644
# Epoch 267/500
#  - 0s - loss: 1.2502
# Epoch 268/500
#  - 0s - loss: 1.2361
# Epoch 269/500
#  - 0s - loss: 1.2222
# Epoch 270/500
#  - 0s - loss: 1.2084
# Epoch 271/500
#  - 0s - loss: 1.1948
# Epoch 272/500
#  - 0s - loss: 1.1814
# Epoch 273/500
#  - 0s - loss: 1.1681
# Epoch 274/500
#  - 0s - loss: 1.1549
# Epoch 275/500
#  - 0s - loss: 1.1419
# Epoch 276/500
#  - 0s - loss: 1.1290
# Epoch 277/500
#  - 0s - loss: 1.1163
# Epoch 278/500
#  - 0s - loss: 1.1037
# Epoch 279/500
#  - 0s - loss: 1.0913
# Epoch 280/500
#  - 0s - loss: 1.0790
# Epoch 281/500
#  - 0s - loss: 1.0669
# Epoch 282/500
#  - 0s - loss: 1.0549
# Epoch 283/500
#  - 0s - loss: 1.0430
# Epoch 284/500
#  - 0s - loss: 1.0312
# Epoch 285/500
#  - 0s - loss: 1.0196
# Epoch 286/500
#  - 0s - loss: 1.0081
# Epoch 287/500
#  - 0s - loss: 0.9968
# Epoch 288/500
#  - 0s - loss: 0.9855
# Epoch 289/500
#  - 0s - loss: 0.9744
# Epoch 290/500
#  - 0s - loss: 0.9635
# Epoch 291/500
#  - 0s - loss: 0.9526
# Epoch 292/500
#  - 0s - loss: 0.9419
# Epoch 293/500
#  - 0s - loss: 0.9313
# Epoch 294/500
#  - 0s - loss: 0.9208
# Epoch 295/500
#  - 0s - loss: 0.9104
# Epoch 296/500
#  - 0s - loss: 0.9002
# Epoch 297/500
#  - 0s - loss: 0.8900
# Epoch 298/500
#  - 0s - loss: 0.8800
# Epoch 299/500
#  - 0s - loss: 0.8701
# Epoch 300/500
#  - 0s - loss: 0.8603
# Epoch 301/500
#  - 0s - loss: 0.8506
# Epoch 302/500
#  - 0s - loss: 0.8410
# Epoch 303/500
#  - 0s - loss: 0.8316
# Epoch 304/500
#  - 0s - loss: 0.8222
# Epoch 305/500
#  - 0s - loss: 0.8129
# Epoch 306/500
#  - 0s - loss: 0.8038
# Epoch 307/500
#  - 0s - loss: 0.7947
# Epoch 308/500
#  - 0s - loss: 0.7858
# Epoch 309/500
#  - 0s - loss: 0.7769
# Epoch 310/500
#  - 0s - loss: 0.7682
# Epoch 311/500
#  - 0s - loss: 0.7595
# Epoch 312/500
#  - 0s - loss: 0.7510
# Epoch 313/500
#  - 0s - loss: 0.7425
# Epoch 314/500
#  - 0s - loss: 0.7341
# Epoch 315/500
#  - 0s - loss: 0.7259
# Epoch 316/500
#  - 0s - loss: 0.7177
# Epoch 317/500
#  - 0s - loss: 0.7096
# Epoch 318/500
#  - 0s - loss: 0.7016
# Epoch 319/500
#  - 0s - loss: 0.6937
# Epoch 320/500
#  - 0s - loss: 0.6859
# Epoch 321/500
#  - 0s - loss: 0.6782
# Epoch 322/500
#  - 0s - loss: 0.6705
# Epoch 323/500
#  - 0s - loss: 0.6630
# Epoch 324/500
#  - 0s - loss: 0.6555
# Epoch 325/500
#  - 0s - loss: 0.6481
# Epoch 326/500
#  - 0s - loss: 0.6408
# Epoch 327/500
#  - 0s - loss: 0.6336
# Epoch 328/500
#  - 0s - loss: 0.6265
# Epoch 329/500
#  - 0s - loss: 0.6194
# Epoch 330/500
#  - 0s - loss: 0.6125
# Epoch 331/500
#  - 0s - loss: 0.6056
# Epoch 332/500
#  - 0s - loss: 0.5987
# Epoch 333/500
#  - 0s - loss: 0.5920
# Epoch 334/500
#  - 0s - loss: 0.5853
# Epoch 335/500
#  - 0s - loss: 0.5787
# Epoch 336/500
#  - 0s - loss: 0.5722
# Epoch 337/500
#  - 0s - loss: 0.5658
# Epoch 338/500
#  - 0s - loss: 0.5594
# Epoch 339/500
#  - 0s - loss: 0.5531
# Epoch 340/500
#  - 0s - loss: 0.5469
# Epoch 341/500
#  - 0s - loss: 0.5407
# Epoch 342/500
#  - 0s - loss: 0.5346
# Epoch 343/500
#  - 0s - loss: 0.5286
# Epoch 344/500
#  - 0s - loss: 0.5227
# Epoch 345/500
#  - 0s - loss: 0.5168
# Epoch 346/500
#  - 0s - loss: 0.5109
# Epoch 347/500
#  - 0s - loss: 0.5052
# Epoch 348/500
#  - 0s - loss: 0.4995
# Epoch 349/500
#  - 0s - loss: 0.4939
# Epoch 350/500
#  - 0s - loss: 0.4883
# Epoch 351/500
#  - 0s - loss: 0.4828
# Epoch 352/500
#  - 0s - loss: 0.4774
# Epoch 353/500
#  - 0s - loss: 0.4720
# Epoch 354/500
#  - 0s - loss: 0.4667
# Epoch 355/500
#  - 0s - loss: 0.4614
# Epoch 356/500
#  - 0s - loss: 0.4562
# Epoch 357/500
#  - 0s - loss: 0.4511
# Epoch 358/500
#  - 0s - loss: 0.4460
# Epoch 359/500
#  - 0s - loss: 0.4410
# Epoch 360/500
#  - 0s - loss: 0.4360
# Epoch 361/500
#  - 0s - loss: 0.4311
# Epoch 362/500
#  - 0s - loss: 0.4263
# Epoch 363/500
#  - 0s - loss: 0.4215
# Epoch 364/500
#  - 0s - loss: 0.4167
# Epoch 365/500
#  - 0s - loss: 0.4120
# Epoch 366/500
#  - 0s - loss: 0.4074
# Epoch 367/500
#  - 0s - loss: 0.4028
# Epoch 368/500
#  - 0s - loss: 0.3982
# Epoch 369/500
#  - 0s - loss: 0.3938
# Epoch 370/500
#  - 0s - loss: 0.3893
# Epoch 371/500
#  - 0s - loss: 0.3849
# Epoch 372/500
#  - 0s - loss: 0.3806
# Epoch 373/500
#  - 0s - loss: 0.3763
# Epoch 374/500
#  - 0s - loss: 0.3721
# Epoch 375/500
#  - 0s - loss: 0.3679
# Epoch 376/500
#  - 0s - loss: 0.3637
# Epoch 377/500
#  - 0s - loss: 0.3597
# Epoch 378/500
#  - 0s - loss: 0.3556
# Epoch 379/500
#  - 0s - loss: 0.3516
# Epoch 380/500
#  - 0s - loss: 0.3476
# Epoch 381/500
#  - 0s - loss: 0.3437
# Epoch 382/500
#  - 0s - loss: 0.3398
# Epoch 383/500
#  - 0s - loss: 0.3360
# Epoch 384/500
#  - 0s - loss: 0.3322
# Epoch 385/500
#  - 0s - loss: 0.3285
# Epoch 386/500
#  - 0s - loss: 0.3248
# Epoch 387/500
#  - 0s - loss: 0.3211
# Epoch 388/500
#  - 0s - loss: 0.3175
# Epoch 389/500
#  - 0s - loss: 0.3139
# Epoch 390/500
#  - 0s - loss: 0.3104
# Epoch 391/500
#  - 0s - loss: 0.3069
# Epoch 392/500
#  - 0s - loss: 0.3035
# Epoch 393/500
#  - 0s - loss: 0.3000
# Epoch 394/500
#  - 0s - loss: 0.2967
# Epoch 395/500
#  - 0s - loss: 0.2933
# Epoch 396/500
#  - 0s - loss: 0.2900
# Epoch 397/500
#  - 0s - loss: 0.2867
# Epoch 398/500
#  - 0s - loss: 0.2835
# Epoch 399/500
#  - 0s - loss: 0.2803
# Epoch 400/500
#  - 0s - loss: 0.2772
# Epoch 401/500
#  - 0s - loss: 0.2740
# Epoch 402/500
#  - 0s - loss: 0.2710
# Epoch 403/500
#  - 0s - loss: 0.2679
# Epoch 404/500
#  - 0s - loss: 0.2649
# Epoch 405/500
#  - 0s - loss: 0.2619
# Epoch 406/500
#  - 0s - loss: 0.2590
# Epoch 407/500
#  - 0s - loss: 0.2560
# Epoch 408/500
#  - 0s - loss: 0.2532
# Epoch 409/500
#  - 0s - loss: 0.2503
# Epoch 410/500
#  - 0s - loss: 0.2475
# Epoch 411/500
#  - 0s - loss: 0.2447
# Epoch 412/500
#  - 0s - loss: 0.2419
# Epoch 413/500
#  - 0s - loss: 0.2392
# Epoch 414/500
#  - 0s - loss: 0.2365
# Epoch 415/500
#  - 0s - loss: 0.2339
# Epoch 416/500
#  - 0s - loss: 0.2312
# Epoch 417/500
#  - 0s - loss: 0.2286
# Epoch 418/500
#  - 0s - loss: 0.2260
# Epoch 419/500
#  - 0s - loss: 0.2235
# Epoch 420/500
#  - 0s - loss: 0.2210
# Epoch 421/500
#  - 0s - loss: 0.2185
# Epoch 422/500
#  - 0s - loss: 0.2160
# Epoch 423/500
#  - 0s - loss: 0.2136
# Epoch 424/500
#  - 0s - loss: 0.2112
# Epoch 425/500
#  - 0s - loss: 0.2088
# Epoch 426/500
#  - 0s - loss: 0.2065
# Epoch 427/500
#  - 0s - loss: 0.2041
# Epoch 428/500
#  - 0s - loss: 0.2018
# Epoch 429/500
#  - 0s - loss: 0.1996
# Epoch 430/500
#  - 0s - loss: 0.1973
# Epoch 431/500
#  - 0s - loss: 0.1951
# Epoch 432/500
#  - 0s - loss: 0.1929
# Epoch 433/500
#  - 0s - loss: 0.1907
# Epoch 434/500
#  - 0s - loss: 0.1886
# Epoch 435/500
#  - 0s - loss: 0.1865
# Epoch 436/500
#  - 0s - loss: 0.1844
# Epoch 437/500
#  - 0s - loss: 0.1823
# Epoch 438/500
#  - 0s - loss: 0.1802
# Epoch 439/500
#  - 0s - loss: 0.1782
# Epoch 440/500
#  - 0s - loss: 0.1762
# Epoch 441/500
#  - 0s - loss: 0.1742
# Epoch 442/500
#  - 0s - loss: 0.1722
# Epoch 443/500
#  - 0s - loss: 0.1703
# Epoch 444/500
#  - 0s - loss: 0.1684
# Epoch 445/500
#  - 0s - loss: 0.1665
# Epoch 446/500
#  - 0s - loss: 0.1646
# Epoch 447/500
#  - 0s - loss: 0.1628
# Epoch 448/500
#  - 0s - loss: 0.1609
# Epoch 449/500
#  - 0s - loss: 0.1591
# Epoch 450/500
#  - 0s - loss: 0.1573
# Epoch 451/500
#  - 0s - loss: 0.1556
# Epoch 452/500
#  - 0s - loss: 0.1538
# Epoch 453/500
#  - 0s - loss: 0.1521
# Epoch 454/500
#  - 0s - loss: 0.1504
# Epoch 455/500
#  - 0s - loss: 0.1487
# Epoch 456/500
#  - 0s - loss: 0.1470
# Epoch 457/500
#  - 0s - loss: 0.1453
# Epoch 458/500
#  - 0s - loss: 0.1437
# Epoch 459/500
#  - 0s - loss: 0.1421
# Epoch 460/500
#  - 0s - loss: 0.1405
# Epoch 461/500
#  - 0s - loss: 0.1389
# Epoch 462/500
#  - 0s - loss: 0.1373
# Epoch 463/500
#  - 0s - loss: 0.1358
# Epoch 464/500
#  - 0s - loss: 0.1343
# Epoch 465/500
#  - 0s - loss: 0.1327
# Epoch 466/500
#  - 0s - loss: 0.1312
# Epoch 467/500
#  - 0s - loss: 0.1298
# Epoch 468/500
#  - 0s - loss: 0.1283
# Epoch 469/500
#  - 0s - loss: 0.1269
# Epoch 470/500
#  - 0s - loss: 0.1254
# Epoch 471/500
#  - 0s - loss: 0.1240
# Epoch 472/500
#  - 0s - loss: 0.1226
# Epoch 473/500
#  - 0s - loss: 0.1212
# Epoch 474/500
#  - 0s - loss: 0.1199
# Epoch 475/500
#  - 0s - loss: 0.1185
# Epoch 476/500
#  - 0s - loss: 0.1172
# Epoch 477/500
#  - 0s - loss: 0.1159
# Epoch 478/500
#  - 0s - loss: 0.1146
# Epoch 479/500
#  - 0s - loss: 0.1133
# Epoch 480/500
#  - 0s - loss: 0.1120
# Epoch 481/500
#  - 0s - loss: 0.1107
# Epoch 482/500
#  - 0s - loss: 0.1095
# Epoch 483/500
#  - 0s - loss: 0.1083
# Epoch 484/500
#  - 0s - loss: 0.1070
# Epoch 485/500
#  - 0s - loss: 0.1058
# Epoch 486/500
#  - 0s - loss: 0.1046
# Epoch 487/500
#  - 0s - loss: 0.1035
# Epoch 488/500
#  - 0s - loss: 0.1023
# Epoch 489/500
#  - 0s - loss: 0.1011
# Epoch 490/500
#  - 0s - loss: 0.1000
# Epoch 491/500
#  - 0s - loss: 0.0989
# Epoch 492/500
#  - 0s - loss: 0.0978
# Epoch 493/500
#  - 0s - loss: 0.0967
# Epoch 494/500
#  - 0s - loss: 0.0956
# Epoch 495/500
#  - 0s - loss: 0.0945
# Epoch 496/500
#  - 0s - loss: 0.0934
# Epoch 497/500
#  - 0s - loss: 0.0924
# Epoch 498/500
#  - 0s - loss: 0.0913
# Epoch 499/500
#  - 0s - loss: 0.0903
# Epoch 500/500
#  - 0s - loss: 0.0893
# X: 5, Y:20.000000, Y':19.888107
# X: 2.5, Y:35.000000, Y':14.667950

# %% [markdown]
# # Tensorflow를 이용한 Softmax

# %%
# 털과 날개가 있는지 없는지에 따라, 포유류인지 조류인지 분류하는 신경망 모델을 만들어봅니다.
import tensorflow as tf
import numpy as np

# [털, 날개]
x_data = np.array(
    [[0, 0], [1, 0], [1, 1], [0, 0], [0, 0], [0, 1]])

y_data = np.array([
    [1, 0, 0],  # 기타
    [0, 1, 0],  # 포유류
    [0, 0, 1],  # 조류
    [1, 0, 0],
    [1, 0, 0],
    [0, 0, 1]
])

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

W = tf.Variable(tf.random_uniform([2, 3], -1., 1.))
b = tf.Variable(tf.zeros([3]))
L = tf.add(tf.matmul(X, W), b)
L = tf.nn.relu(L)
model = tf.nn.softmax(L)

cost = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(model), axis=1))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train_op = optimizer.minimize(cost)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
epochs = 200
for step in range(1, epochs+1):
    sess.run(train_op, feed_dict={X: x_data, Y: y_data})

    if (step + 1) % 20 == 0:
        print(step + 1, sess.run(cost, feed_dict={X: x_data, Y: y_data}))

# 결과 확인
# 0: 기타 1: 포유류, 2: 조류
prediction = tf.argmax(model, 1)
target = tf.argmax(Y, 1)
print('예측값:', sess.run(prediction, feed_dict={X: x_data}))
print('실제값:', sess.run(target, feed_dict={Y: y_data}))

is_correct = tf.equal(prediction, target)
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
print('정확도: %.2f' % sess.run(accuracy * 100, feed_dict={X: x_data, Y: y_data}))
# Out:
# 20 1.0556642
# 40 1.0448868
# 60 1.0346571
# 80 1.0249383
# 100 1.0156957
# 120 1.006896
# 140 0.9985078
# 160 0.9911664
# 180 0.984284
# 200 0.97757196
# 예측값: [2 2 2 2 2 2]
# 실제값: [0 1 2 0 0 2]
# 정확도: 33.33

# %% [markdown]
# # Keras를 이용한 Softmax 예제

# %%
# import keras.models as models
import keras.layers as layers
import numpy as np

x_data = np.array(
    [[0, 0], [1, 0], [1, 1], [0, 0], [0, 0], [0, 1]])

y_data = np.array([
    [1, 0, 0],  # 기타
    [0, 1, 0],  # 포유류
    [0, 0, 1],  # 조류
    [1, 0, 0],
    [1, 0, 0],
    [0, 0, 1]
])

model = keras.models.Sequential()
model.add(layers.Dense(3, activation='softmax', input_shape=(2,)))
model.compile('SGD', 'mse')

model.fit(x_data, y_data, epochs=200, verbose=2)

pred = np.argmax(model.predict(x_data), axis=1)
target = np.argmax(y_data, axis=1)
print('예측값:', pred)
print('실제값:', target)
print('정확도: %.2f'% (np.sum(pred == target)/target.shape[0]*100))
# Out:
# Epoch 1/200
#  - 0s - loss: 0.1972
# Epoch 2/200
#  - 0s - loss: 0.1971
# Epoch 3/200
#  - 0s - loss: 0.1970
# Epoch 4/200
#  - 0s - loss: 0.1969
# Epoch 5/200
#  - 0s - loss: 0.1969
# Epoch 6/200
#  - 0s - loss: 0.1968
# Epoch 7/200
#  - 0s - loss: 0.1967
# Epoch 8/200
#  - 0s - loss: 0.1967
# Epoch 9/200
#  - 0s - loss: 0.1966
# Epoch 10/200
#  - 0s - loss: 0.1965
# Epoch 11/200
#  - 0s - loss: 0.1965
# Epoch 12/200
#  - 0s - loss: 0.1964
# Epoch 13/200
#  - 0s - loss: 0.1963
# Epoch 14/200
#  - 0s - loss: 0.1963
# Epoch 15/200
#  - 0s - loss: 0.1962
# Epoch 16/200
#  - 0s - loss: 0.1961
# Epoch 17/200
#  - 0s - loss: 0.1960
# Epoch 18/200
#  - 0s - loss: 0.1960
# Epoch 19/200
#  - 0s - loss: 0.1959
# Epoch 20/200
#  - 0s - loss: 0.1958
# Epoch 21/200
#  - 0s - loss: 0.1958
# Epoch 22/200
#  - 0s - loss: 0.1957
# Epoch 23/200
#  - 0s - loss: 0.1956
# Epoch 24/200
#  - 0s - loss: 0.1956
# Epoch 25/200
#  - 0s - loss: 0.1955
# Epoch 26/200
#  - 0s - loss: 0.1954
# Epoch 27/200
#  - 0s - loss: 0.1954
# Epoch 28/200
#  - 0s - loss: 0.1953
# Epoch 29/200
#  - 0s - loss: 0.1952
# Epoch 30/200
#  - 0s - loss: 0.1952
# Epoch 31/200
#  - 0s - loss: 0.1951
# Epoch 32/200
#  - 0s - loss: 0.1950
# Epoch 33/200
#  - 0s - loss: 0.1949
# Epoch 34/200
#  - 0s - loss: 0.1949
# Epoch 35/200
#  - 0s - loss: 0.1948
# Epoch 36/200
#  - 0s - loss: 0.1947
# Epoch 37/200
#  - 0s - loss: 0.1947
# Epoch 38/200
#  - 0s - loss: 0.1946
# Epoch 39/200
#  - 0s - loss: 0.1945
# Epoch 40/200
#  - 0s - loss: 0.1945
# Epoch 41/200
#  - 0s - loss: 0.1944
# Epoch 42/200
#  - 0s - loss: 0.1943
# Epoch 43/200
#  - 0s - loss: 0.1943
# Epoch 44/200
#  - 0s - loss: 0.1942
# Epoch 45/200
#  - 0s - loss: 0.1941
# Epoch 46/200
#  - 0s - loss: 0.1941
# Epoch 47/200
#  - 0s - loss: 0.1940
# Epoch 48/200
#  - 0s - loss: 0.1939
# Epoch 49/200
#  - 0s - loss: 0.1938
# Epoch 50/200
#  - 0s - loss: 0.1938
# Epoch 51/200
#  - 0s - loss: 0.1937
# Epoch 52/200
#  - 0s - loss: 0.1936
# Epoch 53/200
#  - 0s - loss: 0.1936
# Epoch 54/200
#  - 0s - loss: 0.1935
# Epoch 55/200
#  - 0s - loss: 0.1934
# Epoch 56/200
#  - 0s - loss: 0.1934
# Epoch 57/200
#  - 0s - loss: 0.1933
# Epoch 58/200
#  - 0s - loss: 0.1932
# Epoch 59/200
#  - 0s - loss: 0.1932
# Epoch 60/200
#  - 0s - loss: 0.1931
# Epoch 61/200
#  - 0s - loss: 0.1930
# Epoch 62/200
#  - 0s - loss: 0.1930
# Epoch 63/200
#  - 0s - loss: 0.1929
# Epoch 64/200
#  - 0s - loss: 0.1928
# Epoch 65/200
#  - 0s - loss: 0.1928
# Epoch 66/200
#  - 0s - loss: 0.1927
# Epoch 67/200
#  - 0s - loss: 0.1926
# Epoch 68/200
#  - 0s - loss: 0.1926
# Epoch 69/200
#  - 0s - loss: 0.1925
# Epoch 70/200
#  - 0s - loss: 0.1924
# Epoch 71/200
#  - 0s - loss: 0.1924
# Epoch 72/200
#  - 0s - loss: 0.1923
# Epoch 73/200
#  - 0s - loss: 0.1922
# Epoch 74/200
#  - 0s - loss: 0.1922
# Epoch 75/200
#  - 0s - loss: 0.1921
# Epoch 76/200
#  - 0s - loss: 0.1920
# Epoch 77/200
#  - 0s - loss: 0.1919
# Epoch 78/200
#  - 0s - loss: 0.1919
# Epoch 79/200
#  - 0s - loss: 0.1918
# Epoch 80/200
#  - 0s - loss: 0.1917
# Epoch 81/200
#  - 0s - loss: 0.1917
# Epoch 82/200
#  - 0s - loss: 0.1916
# Epoch 83/200
#  - 0s - loss: 0.1915
# Epoch 84/200
#  - 0s - loss: 0.1915
# Epoch 85/200
#  - 0s - loss: 0.1914
# Epoch 86/200
#  - 0s - loss: 0.1913
# Epoch 87/200
#  - 0s - loss: 0.1913
# Epoch 88/200
#  - 0s - loss: 0.1912
# Epoch 89/200
#  - 0s - loss: 0.1911
# Epoch 90/200
#  - 0s - loss: 0.1911
# Epoch 91/200
#  - 0s - loss: 0.1910
# Epoch 92/200
#  - 0s - loss: 0.1909
# Epoch 93/200
#  - 0s - loss: 0.1909
# Epoch 94/200
#  - 0s - loss: 0.1908
# Epoch 95/200
#  - 0s - loss: 0.1907
# Epoch 96/200
#  - 0s - loss: 0.1907
# Epoch 97/200
#  - 0s - loss: 0.1906
# Epoch 98/200
#  - 0s - loss: 0.1905
# Epoch 99/200
#  - 0s - loss: 0.1905
# Epoch 100/200
#  - 0s - loss: 0.1904
# Epoch 101/200
#  - 0s - loss: 0.1903
# Epoch 102/200
#  - 0s - loss: 0.1903
# Epoch 103/200
#  - 0s - loss: 0.1902
# Epoch 104/200
#  - 0s - loss: 0.1901
# Epoch 105/200
#  - 0s - loss: 0.1901
# Epoch 106/200
#  - 0s - loss: 0.1900
# Epoch 107/200
#  - 0s - loss: 0.1899
# Epoch 108/200
#  - 0s - loss: 0.1899
# Epoch 109/200
#  - 0s - loss: 0.1898
# Epoch 110/200
#  - 0s - loss: 0.1897
# Epoch 111/200
#  - 0s - loss: 0.1897
# Epoch 112/200
#  - 0s - loss: 0.1896
# Epoch 113/200
#  - 0s - loss: 0.1895
# Epoch 114/200
#  - 0s - loss: 0.1895
# Epoch 115/200
#  - 0s - loss: 0.1894
# Epoch 116/200
#  - 0s - loss: 0.1893
# Epoch 117/200
#  - 0s - loss: 0.1893
# Epoch 118/200
#  - 0s - loss: 0.1892
# Epoch 119/200
#  - 0s - loss: 0.1891
# Epoch 120/200
#  - 0s - loss: 0.1891
# Epoch 121/200
#  - 0s - loss: 0.1890
# Epoch 122/200
#  - 0s - loss: 0.1889
# Epoch 123/200
#  - 0s - loss: 0.1889
# Epoch 124/200
#  - 0s - loss: 0.1888
# Epoch 125/200
#  - 0s - loss: 0.1887
# Epoch 126/200
#  - 0s - loss: 0.1887
# Epoch 127/200
#  - 0s - loss: 0.1886
# Epoch 128/200
#  - 0s - loss: 0.1885
# Epoch 129/200
#  - 0s - loss: 0.1885
# Epoch 130/200
#  - 0s - loss: 0.1884
# Epoch 131/200
#  - 0s - loss: 0.1883
# Epoch 132/200
#  - 0s - loss: 0.1883
# Epoch 133/200
#  - 0s - loss: 0.1882
# Epoch 134/200
#  - 0s - loss: 0.1881
# Epoch 135/200
#  - 0s - loss: 0.1881
# Epoch 136/200
#  - 0s - loss: 0.1880
# Epoch 137/200
#  - 0s - loss: 0.1880
# Epoch 138/200
#  - 0s - loss: 0.1879
# Epoch 139/200
#  - 0s - loss: 0.1878
# Epoch 140/200
#  - 0s - loss: 0.1878
# Epoch 141/200
#  - 0s - loss: 0.1877
# Epoch 142/200
#  - 0s - loss: 0.1876
# Epoch 143/200
#  - 0s - loss: 0.1876
# Epoch 144/200
#  - 0s - loss: 0.1875
# Epoch 145/200
#  - 0s - loss: 0.1874
# Epoch 146/200
#  - 0s - loss: 0.1874
# Epoch 147/200
#  - 0s - loss: 0.1873
# Epoch 148/200
#  - 0s - loss: 0.1872
# Epoch 149/200
#  - 0s - loss: 0.1872
# Epoch 150/200
#  - 0s - loss: 0.1871
# Epoch 151/200
#  - 0s - loss: 0.1870
# Epoch 152/200
#  - 0s - loss: 0.1870
# Epoch 153/200
#  - 0s - loss: 0.1869
# Epoch 154/200
#  - 0s - loss: 0.1868
# Epoch 155/200
#  - 0s - loss: 0.1868
# Epoch 156/200
#  - 0s - loss: 0.1867
# Epoch 157/200
#  - 0s - loss: 0.1866
# Epoch 158/200
#  - 0s - loss: 0.1866
# Epoch 159/200
#  - 0s - loss: 0.1865
# Epoch 160/200
#  - 0s - loss: 0.1864
# Epoch 161/200
#  - 0s - loss: 0.1864
# Epoch 162/200
#  - 0s - loss: 0.1863
# Epoch 163/200
#  - 0s - loss: 0.1863
# Epoch 164/200
#  - 0s - loss: 0.1862
# Epoch 165/200
#  - 0s - loss: 0.1861
# Epoch 166/200
#  - 0s - loss: 0.1861
# Epoch 167/200
#  - 0s - loss: 0.1860
# Epoch 168/200
#  - 0s - loss: 0.1859
# Epoch 169/200
#  - 0s - loss: 0.1859
# Epoch 170/200
#  - 0s - loss: 0.1858
# Epoch 171/200
#  - 0s - loss: 0.1857
# Epoch 172/200
#  - 0s - loss: 0.1857
# Epoch 173/200
#  - 0s - loss: 0.1856
# Epoch 174/200
#  - 0s - loss: 0.1855
# Epoch 175/200
#  - 0s - loss: 0.1855
# Epoch 176/200
#  - 0s - loss: 0.1854
# Epoch 177/200
#  - 0s - loss: 0.1853
# Epoch 178/200
#  - 0s - loss: 0.1853
# Epoch 179/200
#  - 0s - loss: 0.1852
# Epoch 180/200
#  - 0s - loss: 0.1851
# Epoch 181/200
#  - 0s - loss: 0.1851
# Epoch 182/200
#  - 0s - loss: 0.1850
# Epoch 183/200
#  - 0s - loss: 0.1850
# Epoch 184/200
#  - 0s - loss: 0.1849
# Epoch 185/200
#  - 0s - loss: 0.1848
# Epoch 186/200
#  - 0s - loss: 0.1848
# Epoch 187/200
#  - 0s - loss: 0.1847
# Epoch 188/200
#  - 0s - loss: 0.1846
# Epoch 189/200
#  - 0s - loss: 0.1846
# Epoch 190/200
#  - 0s - loss: 0.1845
# Epoch 191/200
#  - 0s - loss: 0.1844
# Epoch 192/200
#  - 0s - loss: 0.1844
# Epoch 193/200
#  - 0s - loss: 0.1843
# Epoch 194/200
#  - 0s - loss: 0.1842
# Epoch 195/200
#  - 0s - loss: 0.1842
# Epoch 196/200
#  - 0s - loss: 0.1841
# Epoch 197/200
#  - 0s - loss: 0.1841
# Epoch 198/200
#  - 0s - loss: 0.1840
# Epoch 199/200
#  - 0s - loss: 0.1839
# Epoch 200/200
#  - 0s - loss: 0.1839
# 예측값: [0 2 2 0 0 2]
# 실제값: [0 1 2 0 0 2]
# 정확도: 83.33
